# %%
import networkx as nx
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os 

import utilities as ut
import construction as cs
import SingleDatasetAnalysis as ans
import MultipleDatasetAnalysis as anm
# %load_ext autoreload
# %autoreload 2

from IPython.core.display import HTML
HTML('<style>.container { width:97% !important; }</style><style>.output_png {display: table-cell;text-align: center;vertical-align: middle;}</style>')
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# <style>.container { width:97% !important; }</style><style>.output_png {display: table-cell;text-align: center;vertical-align: middle;}</style>

# %%
# load data

# %%
file = "data/co-presence/"

files = [f for f in os.listdir(file) if f.split(".")[-1] == "dat"]
data_sets = []
for i in files:
    data_sets.append(cs.load_data(file+i))

# %%
# convert to dict name: data
data = dict()
for i in range(len(data_sets)):
    data[files[i]] = data_sets[i]# smallest datasets- test purpouse #[0:10000]

# %%
anm.plot_assortativivity_degree_graphs(data,gap=19,save=True)

# %%
anm.plot_assortativivity_weights_graphs(data,gap=19,save=True)

# %%
anm.plot_dist_eigvals_graphs(data,binary_adj_matrix=False,gap=19,save=True)

# %%
anm.plot_dist_eigvals_graphs(data,binary_adj_matrix=True,gap=19,save=True)

# %%
anm.plot_dist_degree_graphs(data,normed=True,density=True,gap=19,bins=40,save=True)

# %%
anm.plot_dist_weights_graphs(data,normed=True,density=True,gap=19,bins=40,save=True)

# %%
anm.plot_dist_neigh_weights_graphs(data,normed=True,density=True,gap=19,bins=40,save=True)

# %%
anm.plot_dist_closeness_cent_graphs(data,normed=True,density=True,gap=19,bins=40,save=True)

# %%
anm.plot_dist_between_cent_graphs(data,normed=True,density=True,gap=19,bins=40,save=True)

# %%
anm.plot_dist_clust_coeff_graphs(data,normed=True,density=True,gap=19,bins=40,save=True)

# %%
anm.summary_graphs(data,gap=19,save=True)
# Out:
# 1
# 2
# 3
# 4
#                                    LH10.dat      InVS13.dat        SFHH.dat      InVS15.dat
# ---------------------  --------  ----------  --------------  --------------  --------------
# Spectral GAP           w matrix      0.065      0.2122          0.6737          0.2977
# Spectral GAP           b matrix      0.6408     0.8588          0.9169          0.7163
# Power low NODE_WEIGHT  a             0.2659     1.6512          2.7331          2.1635
# Power low NODE_WEIGHT  c             7.7452     2.74588e+11     1.40614e+12     3.16992e+12
# Power low NODE_WEIGHT  cut           0       4937            5573            9749
# Power low NODE_NEIG    a             0.5791     3.2288          3.1111          2.7915
# Power low NODE_NEIG    c           219.926      7.5277e+12      2.0311e+13      1.77809e+12
# Power low NODE_NEIG    cut        2133       1280             400            3951
